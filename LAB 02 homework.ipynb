# %%
# !pip install python-terrier NLTK
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pyterrier as pt
if not pt.started():
  pt.init()

# %%
#we need to import the following libraries.
import pandas as pd
#to display the full text on the notebook without truncation
pd.set_option('display.max_colwidth', 150)
import re
from snowballstemmer import stemmer
#make your loops show a smart progress meter
from tqdm import tqdm

# %%
with open('/content/Article.txt') as f:
    contents = f.read()
    print(contents)
# Out:
# It was late July of last year, July of last year, which is to say that Mike Magnante had picked a bad time to pitch poorly. Mags, as everyone called him, had come in against Cleveland in the top of the seventh with two runners on and a three-run lead. The first thing he did was to walk Jim Thome -- no one could blame him for that. He then gave up a bloop single to Milton Bradley, and the inherited runners scored -- just plain bad luck, that. But then he threw three straight balls to Lee Stevens. Stevens dutifully took a strike, then waited for Mags to throw his fifth pitch.

# %%
#create a new dataframe
text_df=pd.DataFrame([open('/content/Article.txt')],columns=['Original text'])
text_df
# Out:
#                                                                                                                                            Original text
# 0  It was late July of last year, July of last year, which is to say that Mike Magnante had picked a bad time to pitch poorly. Mags, as everyone call...

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
len(stopwords.words('english'))
# Out:
# 179

# %%
#removing Stop Words function
def remove_stopWords(sentence):
    terms=[]
    stopWords= set(stopwords.words('english'))
    for term in sentence.split() :
        if term not in stopWords :
           terms.append(term)
    return " ".join(terms)

text_df["Removed_Stop_word_text"]=text_df["Original text"].apply(remove_stopWords)
print("***************************************************************************documents after removing stopwords*********************************************************************")
text_df
# Out:
# ***************************************************************************documents after removing stopwords*********************************************************************
#                                                                                                                                            Original text  \
# 0  It was late July of last year, July of last year, which is to say that Mike Magnante had picked a bad time to pitch poorly. Mags, as everyone call...
#
#                                                                                                                                   Removed_Stop_word_text
# 0  It late July last year, July last year, say Mike Magnante picked bad time pitch poorly. Mags, everyone called him, come Cleveland top seventh two ...

# %%
import re
import string
#a function to normalize the tweets
def normalize(text_df):
    string = text_df.lower()
    punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    for ele in string:
        if ele in punc:
            string = string.replace(ele, "")
            
    return(string)

text_df["Normalized_text"]=text_df["Removed_Stop_word_text"].apply(normalize)
print("***************************************************************************documents after normalizing*********************************************************************")
text_df
# Out:
# ***************************************************************************documents after normalizing*********************************************************************
#                                                                                                                                            Original text  \
# 0  It was late July of last year, July of last year, which is to say that Mike Magnante had picked a bad time to pitch poorly. Mags, as everyone call...
#
#                                                                                                                                   Removed_Stop_word_text  \
# 0  It late July last year, July last year, say Mike Magnante picked bad time pitch poorly. Mags, everyone called him, come Cleveland top seventh two ...
#
#                                                                                                                                          Normalized_text
# ...

# %%
#specify that we want to stem arabic text
en_stemmer = stemmer("english")
#define the stemming function
def stem(sentence):
    return " ".join([en_stemmer.stemWord(i) for i in sentence.split()])

text_df['stemmed_text']=text_df['Normalized_text'].apply(stem)
print("***************************************************************************documents after stemming*********************************************************************")
text_df
# Out:
# ***************************************************************************documents after stemming*********************************************************************
#                                                                                                                                            Original text  \
# 0  It was late July of last year, July of last year, which is to say that Mike Magnante had picked a bad time to pitch poorly. Mags, as everyone call...
#
#                                                                                                                                   Removed_Stop_word_text  \
# 0  It late July last year, July last year, say Mike Magnante picked bad time pitch poorly. Mags, everyone called him, come Cleveland top seventh two ...
#
#                                                                                                                                          Normalized_text  \
# ...
